# %%
#dependencies
import pandas as pd
import csv

# %% [markdown]
# # Jan 2020

# %%
# Read Purchasing File and store into Pandas data frame
Jan_df = pd.read_csv("C:/Users/joely/Desktop/Tableau-Challenge/Resources/2020/Jan-2020.csv")

# %%
Jan_df = pd.read_csv(file_to_load)
# Using 'month' as the column name

Jan_df["month"] = "January 2020"
Jan_df.to_csv("file_to_load", index=False)

 
# Observe the result
Jan_df.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           789   00:55.4  14:05.1               504
# 1          1541   01:08.1  26:49.2              3423
# 2          1464   01:42.1  26:07.0              3687
# 3           592   01:45.6  11:38.2               346
# 4           702   01:45.8  13:28.2               372
#
#                 start station name  start station latitude  \
# 0                  1 Ave & E 16 St               40.732219
# 1  West Drive & Prospect Park West               40.661063
# 2                  E 33 St & 1 Ave               40.743227
# 3              Bank St & Hudson St               40.736529
# 4        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# 0               -73.981656             307      Canal St & Rutgers St
# 1               -73.979453            3300  Prospect Park West & 8 St
# 2               -73.974498             259    South St & Whitehall St
# ...

# %% [markdown]
# # Feb 2020

# %%
 
# File to Load
file_to_load = "C:/Users/joely/Desktop/Tableau-Challenge/Resources/2020/Feb-2020.csv"

# Read Purchasing File and store into Pandas data frame
Feb_df = pd.read_csv(file_to_load)

# Using 'month' as the column name

Feb_df["month"] = "February 2020"
Feb_df.to_csv("file_to_load", index=False)

 
# Observe the result
Feb_df.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           789   00:55.4  14:05.1               504
# 1          1541   01:08.1  26:49.2              3423
# 2          1464   01:42.1  26:07.0              3687
# 3           592   01:45.6  11:38.2               346
# 4           702   01:45.8  13:28.2               372
#
#                 start station name  start station latitude  \
# 0                  1 Ave & E 16 St               40.732219
# 1  West Drive & Prospect Park West               40.661063
# 2                  E 33 St & 1 Ave               40.743227
# 3              Bank St & Hudson St               40.736529
# 4        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# 0               -73.981656             307      Canal St & Rutgers St
# 1               -73.979453            3300  Prospect Park West & 8 St
# 2               -73.974498             259    South St & Whitehall St
# ...

# %% [markdown]
# # Merge 2020 Data

# %%
#Merge all 2020 data
Data_Merge = pd.concat([Jan_df, Feb_df], ignore_index=True)

# %%
# Create csv
Data_Merge.to_csv('Resources_Cleaned/data_20.csv', index=False)
