# %%
#dependencies
import pandas as pd
import csv

# %%
# File to Load
file_to_load = "C:/Users/joely/Desktop/Tableau-Challenge/Resources_Cleaned/data_19.csv"

# Read Purchasing File and store into Pandas data frame
df_2019 = pd.read_csv(file_to_load)

# Observe the result
df_2019.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           689   00:04.3  11:33.8              3359
# 1           204   00:05.5  03:30.5              3504
# 2           316   00:10.2  05:27.2               270
# 3           726   00:22.0  12:28.2               495
# 4           397   00:29.6  07:07.4               473
#
#            start station name  start station latitude  \
# 0       E 68 St & Madison Ave               40.769157
# 1    E 123 St & Lexington Ave               40.802926
# 2     Adelphi St & Myrtle Ave               40.693083
# 3            W 47 St & 10 Ave               40.762699
# 4  Rivington St & Chrystie St               40.721101
#
#    start station longitude  end station id            end station name  \
# 0               -73.967035             164             E 47 St & 2 Ave
# 1               -73.937900            3490            E 116 St & 2 Ave
# 2               -73.971789             243     Fulton St & Rockwell Pl
# ...

# %%
# File to Load
file_to_load = "C:/Users/joely/Desktop/Tableau-Challenge/Resources_Cleaned/data_20.csv"

# Read Purchasing File and store into Pandas data frame
df_2020 = pd.read_csv(file_to_load)

# Observe the result
df_2020.head()
# Out:
#    tripduration starttime stoptime  start station id  \
# 0           789   00:55.4  14:05.1               504
# 1          1541   01:08.1  26:49.2              3423
# 2          1464   01:42.1  26:07.0              3687
# 3           592   01:45.6  11:38.2               346
# 4           702   01:45.8  13:28.2               372
#
#                 start station name  start station latitude  \
# 0                  1 Ave & E 16 St               40.732219
# 1  West Drive & Prospect Park West               40.661063
# 2                  E 33 St & 1 Ave               40.743227
# 3              Bank St & Hudson St               40.736529
# 4        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# 0               -73.981656             307      Canal St & Rutgers St
# 1               -73.979453            3300  Prospect Park West & 8 St
# 2               -73.974498             259    South St & Whitehall St
# ...

# %%
#merge 2019 and 2020
merged = pd.concat([df_2019,df_2020],ignore_index=True)
merged
# Out:
#        tripduration starttime stoptime  start station id  \
# 0               689   00:04.3  11:33.8              3359
# 1               204   00:05.5  03:30.5              3504
# 2               316   00:10.2  05:27.2               270
# 3               726   00:22.0  12:28.2               495
# 4               397   00:29.6  07:07.4               473
# ...             ...       ...      ...               ...
# 59210          1508   40:02.8  05:11.1              3323
# 59211           578   40:05.4  49:44.4               251
# 59212           381   40:05.5  46:26.8               458
# 59213            92   40:11.8  41:44.5              3125
# 59214          3718   40:13.9  42:12.2              3363
#
#                  start station name  start station latitude  \
# 0             E 68 St & Madison Ave               40.769157
# 1          E 123 St & Lexington Ave               40.802926
# 2           Adelphi St & Myrtle Ave               40.693083
# ...

# %%
#save merged data as new csv
merged.to_csv('Resources_Cleaned/merged_data.csv', index=False)
